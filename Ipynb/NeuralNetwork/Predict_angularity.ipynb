# %%
# import the data itself
import pandas as pd
from glob import glob
import sys
sys.path.append('../')
import Fit_Model
from JetscapeFileGetter import JetscapeFileGetter
'''
# What is needed:
   Input: 
     tag which matches name of running file (up to the first underscore '_'): A0, A1, etc...
     name of input *.parquet file
   Output:
     make output director
     hard link the input parquet file into that directory
     save output images to that directory
     save output pickled trained models to that directory
'''

files = JetscapeFileGetter(config_path='../config', which='lbt', file_type='parquet')
stem='angularity'
model = Fit_Model.Fit_Model('temp/angularity_W',keras=True)
for file in files:
  print(file.file)
  df = pd.read_parquet(file.file)
  model.fit_plot(file, stem, fraction=1.0, plotAndJSON=True)
# Out:
# ['../config/lbt_brick/gz_files/IP_match_trees/brick_0_maxT_20_nEv_5K_pT_10_11.parquet', '../config/lbt_brick/gz_files/IP_match_trees/brick_0_maxT_20_nEv_5K_pT_40_41.parquet', '../config/lbt_brick/gz_files/IP_match_trees/brick_0_maxT_20_nEv_5K_pT_30_31.parquet']
# 2024-10-22 12:52:49.379987: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-10-22 12:52:49.395081: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-10-22 12:52:49.399759: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# ...
